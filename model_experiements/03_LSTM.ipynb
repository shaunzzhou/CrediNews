# %%
# Import necessary libraries

# Data manipulation
import pandas as pd
import numpy as np

# Statistical functions
from scipy.stats import zscore

# For concurrency (running functions in parallel)
from concurrent.futures import ThreadPoolExecutor

# For caching (to speed up repeated function calls)
from functools import lru_cache

# For progress tracking
from tqdm import tqdm


# Text Preprocessing and NLP
import nltk

# Stopwords (common words to ignore) from NLTK
from nltk.corpus import stopwords

# Tokenizing sentences/words
from nltk.tokenize import word_tokenize

# Part-of-speech tagging
from nltk import pos_tag

# Lemmatization (converting words to their base form)
from nltk.stem import WordNetLemmatizer


# Model Imports
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from gensim.models import Word2Vec

# %%
import os
import sys
from pathlib import Path

if "workding_dir" not in locals():
    workding_dir = str(Path.cwd().parent)
os.chdir(workding_dir)
sys.path.append(workding_dir)
print("working dir:", workding_dir)
# Out:
# working dir: /home/dariusng2103/projects/dm_project/DM-Fake-News-Detection

# %% [markdown]
# ### Load datasets

# %%
from datasets import load_dataset, concatenate_datasets, Dataset

datasets = load_dataset(
    "csv",
    data_files={
        "train": [
            "dataset/train_data_1.csv",
            "dataset/train_data_2.csv",
            "dataset/train_data_3.csv",
            "dataset/train_data_4.csv",
        ],
        "test": "dataset/test_data.csv",
        "rewritten_train": [
            "dataset/rewritten_train_data_1.csv",
            "dataset/rewritten_train_data_2.csv",
            "dataset/rewritten_train_data_3.csv",
            "dataset/rewritten_train_data_4.csv",
        ],
        "rewritten_test": "dataset/rewritten_test_data.csv",
    },
)
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'full_content', 'processed_full_content'],
#         num_rows: 54441
#     })
#     test: Dataset({
#         features: ['label', 'full_content', 'processed_full_content'],
#         num_rows: 6050
#     })
#     rewritten_train: Dataset({
#         features: ['label', 'full_content', 'processed_full_content'],
#         num_rows: 54441
#     })
#     rewritten_test: Dataset({
#         features: ['label', 'full_content', 'processed_full_content'],
#         num_rows: 6050
#     })
# })

# %% [markdown]
# ### LSTM with Word2Vec (best model)

# %%
# Set seeds for reproducibility
import tensorflow as tf
import numpy as np
from gensim.models import Word2Vec
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# Train and process Word2Vec embeddings
def train_word2vec_embeddings(train_texts, word_index, max_words=10000, embedding_dim=100):
    """Tokenizes the text, trains Word2Vec, and creates an embedding matrix."""
    
    # Tokenizing text into word lists
    sentences = [text.split() for text in train_texts]

    # ✅ Train Word2Vec model using processed sentences
    word2vec = Word2Vec(sentences=sentences, vector_size=embedding_dim, window=5, min_count=1, workers=4)

    # ✅ Ensure consistent vocab size (only include words within max_words limit)
    vocab_size = min(max_words, len(word_index) + 1)
    embedding_matrix = np.zeros((vocab_size, embedding_dim))

    for word, i in word_index.items():
        if i < vocab_size and word in word2vec.wv:
            embedding_matrix[i] = word2vec.wv[word]

    return embedding_matrix, vocab_size  # ✅ Returns both embedding matrix & vocab size


def create_lstm_model(vocab_size, embedding_matrix, lstm_units=128, dropout_rate=0.3, learning_rate=0.001, l2_lambda=0.01):
    """Creates an LSTM model with Dropout and L2 regularization."""
    
    model = Sequential([
        Embedding(vocab_size, embedding_matrix.shape[1], weights=[embedding_matrix], trainable=True),
        LSTM(units=lstm_units, return_sequences=False, dropout=dropout_rate), 
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_lambda))
    ])

    # ✅ Use Adam optimizer with a defined learning rate
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate), metrics=['accuracy'])
    
    return model


# ✅ Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# ### Define function to train the model

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def train_model(
    train_data, val_data, epochs=10, batch_size=64, lstm_units=64, dropout_rate=0.3, grid_search=False
):
    """Trains an LSTM model using Word2Vec embeddings while ensuring tokenizer consistency across datasets."""
    
    # ✅ Set random seeds for reproducibility
    seed = 42
    tf.random.set_seed(seed)
    np.random.seed(seed)

    max_words = 10000  # Maximum vocabulary size
    max_sequence_length = 300  # Max length of tokenized sequences
    embedding_dim = 100  # Embedding dimension

    print(f"\n🚀 Training LSTM with lstm_units={lstm_units}, dropout_rate={dropout_rate}")

    # ✅ Extract texts and labels
    train_texts = train_data["processed_full_content"]
    val_texts = val_data["processed_full_content"]
    y_train = train_data["label"]
    y_val = val_data["label"]

    # ✅ Tokenizer is refitted on updated `train_data` for new dataset compatibility
    tokenizer = Tokenizer(num_words=max_words)
    tokenizer.fit_on_texts(train_texts)

    # ✅ Convert texts to sequences and pad them
    X_train = pad_sequences(tokenizer.texts_to_sequences(train_texts), maxlen=max_sequence_length)
    X_val = pad_sequences(tokenizer.texts_to_sequences(val_texts), maxlen=max_sequence_length)

    # ✅ Ensure vocab size consistency (Prevents index mismatches)
    vocab_size = min(max_words, len(tokenizer.word_index) + 1)

    # ✅ Train Word2Vec and get the embedding matrix
    embedding_matrix, _ = train_word2vec_embeddings(train_texts, tokenizer.word_index, max_words, embedding_dim)

    # ✅ Create and compile the LSTM model
    model = create_lstm_model(
        vocab_size=vocab_size,
        embedding_matrix=embedding_matrix,
        lstm_units=lstm_units, 
        dropout_rate=dropout_rate
    )

    # ✅ Train the model with early stopping
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping],
        verbose=1
    )

    # ✅ Evaluate model performance on validation data
    y_pred = (model.predict(X_val) > 0.5).astype(int).reshape(-1)

    accuracy = accuracy_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred)
    recall = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)

    # ✅ Print evaluation metrics
    result = {"accuracy": accuracy, "precision": precision, "recall": recall, "f1_score": f1}
    print("\n🏆 Training Results:")
    for key, value in result.items():
        print(f"🔹 {key.capitalize()}: {value:.4f}")

    return result if grid_search else model

# %% [markdown]
# ### Define Evaluate model function

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
import pandas as pd
from tqdm import tqdm


def evaluate_model(model, train_data, val_data):
    print("Evaluating Model")

    max_words = 10000
    max_sequence_length = 300

    train_texts = train_data["processed_full_content"]
    tokenizer = Tokenizer(num_words=max_words)
    tokenizer.fit_on_texts(train_texts)

    y_val = val_data["label"]
    val_texts = val_data["processed_full_content"]

    X_val = pad_sequences(
        tokenizer.texts_to_sequences(val_texts), maxlen=max_sequence_length
    )
    y_pred = (model.predict(X_val) > 0.5).astype(int)

    accuracy = accuracy_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred)
    recall = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1: {f1:.4f}")

# %% [markdown]
# ### Define GridSearch Function

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

def do_grid_search(data):
    """Performs Grid Search to find the best LSTM hyperparameters using cross-validation."""
    param_grid = {"lstm_units": [64, 128], "dropout_rate": [0.2, 0.3]}
    results = []
    best_score = 0
    best_params = None

    if data.empty:
        raise ValueError("The dataset is empty. Please provide valid data.")

    for lstm_unit in param_grid["lstm_units"]:
        for dropout_rate in param_grid["dropout_rate"]:
            print(f"\n Testing lstm_units={lstm_unit}, dropout_rate={dropout_rate}")

            kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
            fold_scores = []

            for fold, (train_idx, val_idx) in enumerate(
                kfold.split(data["processed_full_content"], data["label"].to_numpy()), 1  
            ):
                print(f"Fold {fold}")

                try:
                    train_data = data.iloc[train_idx]
                    val_data = data.iloc[val_idx]

                    result = train_model(
                        train_data=train_data,
                        val_data=val_data,
                        lstm_units=lstm_unit,
                        dropout_rate=dropout_rate,
                        grid_search=True,
                    )

                    fold_score = result["f1_score"]
                    fold_scores.append(fold_score)
                    print(f"✔️ Fold {fold} F1-score: {fold_score:.4f}")

                except Exception as e:
                    print(f"Fold {fold} failed due to error: {e}")
                    continue

            avg_score = np.mean(fold_scores) if fold_scores else 0
            print(f"Average F1-score: {avg_score:.4f}")

            results.append({"lstm_units": lstm_unit, "dropout_rate": dropout_rate, "avg_f1_score": avg_score})

            if avg_score > best_score:
                best_score = avg_score
                best_params = {"lstm_units": lstm_unit, "dropout_rate": dropout_rate}

    # ✅ Edge case: If all folds fail
    if best_params is not None:
        print("Best Parameters Found:")
        print(f"LSTM Units: {best_params['lstm_units']}")
        print(f"Dropout Rate: {best_params['dropout_rate']}")
        print(f"Best F1-Score: {best_score:.4f}")
    else:
        print("Grid search failed—no valid results.")

    return best_params

# %% [markdown]
# ### Set training and validation data

# %%
train_data = datasets["train"].to_pandas()
val_data = datasets["test"].to_pandas()
data = pd.concat([train_data, val_data], ignore_index=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60491 entries, 0 to 60490
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   label                   60491 non-null  int64
#  1   full_content            60491 non-null  object
#  2   processed_full_content  60491 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Perform grid search for optimal hyperparameters

# %%
# %%time

best_params = do_grid_search(data)
best_params
# Out:
#  Testing lstm_units=64, dropout_rate=0.2
# Fold 1
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.8857 - loss: 0.2930 - val_accuracy: 0.9495 - val_loss: 0.1513
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9581 - loss: 0.1265 - val_accuracy: 0.9683 - val_loss: 0.1023
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9699 - loss: 0.0991 - val_accuracy: 0.9717 - val_loss: 0.0951
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9739 - loss: 0.0863 - val_accuracy: 0.9757 - val_loss: 0.0822
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9809 - loss: 0.0685 - val_accuracy: 0.9778 - val_loss: 0.0733
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9829 - loss: 0.0629 - val_accuracy: 0.9792 - val_loss: 0.0729
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9863 - loss: 0.0546 - val_accuracy: 0.9798 - val_loss: 0.0719
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9892 - loss: 0.0466 - val_accuracy: 0.9802 - val_loss: 0.0707
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9906 - loss: 0.0433 - val_accuracy: 0.9786 - val_loss: 0.0774
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9896 - loss: 0.0443 - val_accuracy: 0.9812 - val_loss: 0.0657
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9811
# 🔹 Precision: 0.9759
# 🔹 Recall: 0.9809
# 🔹 F1_score: 0.9784
# ✔️ Fold 1 F1-score: 0.9784
# Fold 2
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.8773 - loss: 0.2987 - val_accuracy: 0.9535 - val_loss: 0.1429
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9607 - loss: 0.1257 - val_accuracy: 0.9673 - val_loss: 0.1017
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9700 - loss: 0.0959 - val_accuracy: 0.9712 - val_loss: 0.0920
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9765 - loss: 0.0790 - val_accuracy: 0.9707 - val_loss: 0.0915
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9818 - loss: 0.0649 - val_accuracy: 0.9769 - val_loss: 0.0765
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9846 - loss: 0.0568 - val_accuracy: 0.9766 - val_loss: 0.0778
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9872 - loss: 0.0524 - val_accuracy: 0.9781 - val_loss: 0.0735
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9903 - loss: 0.0437 - val_accuracy: 0.9778 - val_loss: 0.0735
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9919 - loss: 0.0398 - val_accuracy: 0.9774 - val_loss: 0.0810
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9924 - loss: 0.0372 - val_accuracy: 0.9814 - val_loss: 0.0725
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9792
# 🔹 Precision: 0.9732
# 🔹 Recall: 0.9794
# 🔹 F1_score: 0.9763
# ✔️ Fold 2 F1-score: 0.9763
# Fold 3
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8901 - loss: 0.2858 - val_accuracy: 0.9532 - val_loss: 0.1461
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9593 - loss: 0.1308 - val_accuracy: 0.9640 - val_loss: 0.1165
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9675 - loss: 0.1047 - val_accuracy: 0.9720 - val_loss: 0.0937
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9764 - loss: 0.0796 - val_accuracy: 0.9740 - val_loss: 0.0850
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9824 - loss: 0.0661 - val_accuracy: 0.9459 - val_loss: 0.1516
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9802 - loss: 0.0672 - val_accuracy: 0.9780 - val_loss: 0.0753
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9861 - loss: 0.0528 - val_accuracy: 0.9799 - val_loss: 0.0687
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9896 - loss: 0.0469 - val_accuracy: 0.9812 - val_loss: 0.0678
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9911 - loss: 0.0398 - val_accuracy: 0.9802 - val_loss: 0.0737
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9931 - loss: 0.0358 - val_accuracy: 0.9795 - val_loss: 0.0718
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9799
# 🔹 Precision: 0.9770
# 🔹 Recall: 0.9771
# 🔹 F1_score: 0.9770
# ✔️ Fold 3 F1-score: 0.9770
# Fold 4
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8844 - loss: 0.2939 - val_accuracy: 0.9529 - val_loss: 0.1430
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9605 - loss: 0.1242 - val_accuracy: 0.9671 - val_loss: 0.1059
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9724 - loss: 0.0930 - val_accuracy: 0.9718 - val_loss: 0.0958
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9784 - loss: 0.0744 - val_accuracy: 0.9703 - val_loss: 0.0983
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9800 - loss: 0.0709 - val_accuracy: 0.9731 - val_loss: 0.0843
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9858 - loss: 0.0566 - val_accuracy: 0.9772 - val_loss: 0.0813
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9870 - loss: 0.0525 - val_accuracy: 0.9762 - val_loss: 0.0863
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9890 - loss: 0.0470 - val_accuracy: 0.9771 - val_loss: 0.0776
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9919 - loss: 0.0407 - val_accuracy: 0.9779 - val_loss: 0.0826
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9928 - loss: 0.0378 - val_accuracy: 0.9771 - val_loss: 0.0795
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9780
# 🔹 Precision: 0.9763
# 🔹 Recall: 0.9734
# 🔹 F1_score: 0.9748
# ✔️ Fold 4 F1-score: 0.9748
# Fold 5
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.8856 - loss: 0.2876 - val_accuracy: 0.9521 - val_loss: 0.1446
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9586 - loss: 0.1283 - val_accuracy: 0.9669 - val_loss: 0.1042
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9702 - loss: 0.0958 - val_accuracy: 0.9703 - val_loss: 0.0981
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9783 - loss: 0.0776 - val_accuracy: 0.9737 - val_loss: 0.0867
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9827 - loss: 0.0637 - val_accuracy: 0.9707 - val_loss: 0.0923
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9840 - loss: 0.0613 - val_accuracy: 0.9745 - val_loss: 0.0820
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9891 - loss: 0.0483 - val_accuracy: 0.9769 - val_loss: 0.0755
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9893 - loss: 0.0460 - val_accuracy: 0.9738 - val_loss: 0.0818
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9902 - loss: 0.0423 - val_accuracy: 0.9780 - val_loss: 0.0778
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9934 - loss: 0.0361 - val_accuracy: 0.9766 - val_loss: 0.0827
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9761
# 🔹 Precision: 0.9758
# 🔹 Recall: 0.9694
# 🔹 F1_score: 0.9726
# ✔️ Fold 5 F1-score: 0.9726
# Average F1-score: 0.9758
#
#  Testing lstm_units=64, dropout_rate=0.3
# Fold 1
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8682 - loss: 0.3231 - val_accuracy: 0.9493 - val_loss: 0.1520
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9528 - loss: 0.1417 - val_accuracy: 0.9629 - val_loss: 0.1124
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9660 - loss: 0.1091 - val_accuracy: 0.9693 - val_loss: 0.0973
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9734 - loss: 0.0878 - val_accuracy: 0.9724 - val_loss: 0.0926
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9781 - loss: 0.0768 - val_accuracy: 0.9757 - val_loss: 0.0830
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9803 - loss: 0.0707 - val_accuracy: 0.9766 - val_loss: 0.0749
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9831 - loss: 0.0633 - val_accuracy: 0.9778 - val_loss: 0.0785
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9859 - loss: 0.0556 - val_accuracy: 0.9786 - val_loss: 0.0728
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9864 - loss: 0.0521 - val_accuracy: 0.9792 - val_loss: 0.0712
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9886 - loss: 0.0488 - val_accuracy: 0.9778 - val_loss: 0.0750
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9795
# 🔹 Precision: 0.9771
# 🔹 Recall: 0.9760
# 🔹 F1_score: 0.9766
# ✔️ Fold 1 F1-score: 0.9766
# Fold 2
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8581 - loss: 0.3271 - val_accuracy: 0.9516 - val_loss: 0.1476
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9577 - loss: 0.1312 - val_accuracy: 0.9547 - val_loss: 0.1417
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9652 - loss: 0.1112 - val_accuracy: 0.9675 - val_loss: 0.0994
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9719 - loss: 0.0915 - val_accuracy: 0.9689 - val_loss: 0.0980
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9759 - loss: 0.0813 - val_accuracy: 0.9686 - val_loss: 0.0955
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9790 - loss: 0.0738 - val_accuracy: 0.9737 - val_loss: 0.0855
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9818 - loss: 0.0650 - val_accuracy: 0.9748 - val_loss: 0.0842
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9847 - loss: 0.0575 - val_accuracy: 0.9751 - val_loss: 0.0865
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9850 - loss: 0.0579 - val_accuracy: 0.9783 - val_loss: 0.0775
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9868 - loss: 0.0525 - val_accuracy: 0.9758 - val_loss: 0.0795
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9777
# 🔹 Precision: 0.9777
# 🔹 Recall: 0.9711
# 🔹 F1_score: 0.9744
# ✔️ Fold 2 F1-score: 0.9744
# Fold 3
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8748 - loss: 0.3108 - val_accuracy: 0.9517 - val_loss: 0.1491
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9586 - loss: 0.1322 - val_accuracy: 0.9629 - val_loss: 0.1177
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9654 - loss: 0.1087 - val_accuracy: 0.9705 - val_loss: 0.0950
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9697 - loss: 0.0977 - val_accuracy: 0.9728 - val_loss: 0.0900
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9765 - loss: 0.0787 - val_accuracy: 0.9751 - val_loss: 0.0839
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9813 - loss: 0.0684 - val_accuracy: 0.9778 - val_loss: 0.0780
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9831 - loss: 0.0631 - val_accuracy: 0.9758 - val_loss: 0.0796
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9849 - loss: 0.0584 - val_accuracy: 0.9775 - val_loss: 0.0772
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9860 - loss: 0.0521 - val_accuracy: 0.9778 - val_loss: 0.0752
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9882 - loss: 0.0479 - val_accuracy: 0.9803 - val_loss: 0.0701
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9802
# 🔹 Precision: 0.9800
# 🔹 Recall: 0.9745
# 🔹 F1_score: 0.9773
# ✔️ Fold 3 F1-score: 0.9773
# Fold 4
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.8698 - loss: 0.3203 - val_accuracy: 0.9486 - val_loss: 0.1496
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9505 - loss: 0.1474 - val_accuracy: 0.9634 - val_loss: 0.1147
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9687 - loss: 0.1015 - val_accuracy: 0.9703 - val_loss: 0.0957
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9761 - loss: 0.0840 - val_accuracy: 0.9726 - val_loss: 0.0912
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9777 - loss: 0.0770 - val_accuracy: 0.9735 - val_loss: 0.0834
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9825 - loss: 0.0640 - val_accuracy: 0.9748 - val_loss: 0.0818
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9840 - loss: 0.0588 - val_accuracy: 0.9745 - val_loss: 0.0818
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9860 - loss: 0.0540 - val_accuracy: 0.9773 - val_loss: 0.0777
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9881 - loss: 0.0486 - val_accuracy: 0.9774 - val_loss: 0.0799
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9892 - loss: 0.0447 - val_accuracy: 0.9761 - val_loss: 0.0788
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9778
# 🔹 Precision: 0.9756
# 🔹 Recall: 0.9735
# 🔹 F1_score: 0.9746
# ✔️ Fold 4 F1-score: 0.9746
# Fold 5
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.8726 - loss: 0.3123 - val_accuracy: 0.9516 - val_loss: 0.1524
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9555 - loss: 0.1385 - val_accuracy: 0.9568 - val_loss: 0.1264
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9682 - loss: 0.1054 - val_accuracy: 0.9649 - val_loss: 0.1041
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9726 - loss: 0.0894 - val_accuracy: 0.9688 - val_loss: 0.0950
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9777 - loss: 0.0783 - val_accuracy: 0.9712 - val_loss: 0.0873
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9806 - loss: 0.0702 - val_accuracy: 0.9732 - val_loss: 0.0871
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9823 - loss: 0.0646 - val_accuracy: 0.9750 - val_loss: 0.0873
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9841 - loss: 0.0600 - val_accuracy: 0.9748 - val_loss: 0.0794
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9850 - loss: 0.0557 - val_accuracy: 0.9748 - val_loss: 0.0825
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9875 - loss: 0.0504 - val_accuracy: 0.9759 - val_loss: 0.0831
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9733
# 🔹 Precision: 0.9742
# 🔹 Recall: 0.9645
# 🔹 F1_score: 0.9693
# ✔️ Fold 5 F1-score: 0.9693
# Average F1-score: 0.9744
#
#  Testing lstm_units=128, dropout_rate=0.2
# Fold 1
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8997 - loss: 0.2543 - val_accuracy: 0.9647 - val_loss: 0.1088
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9676 - loss: 0.1023 - val_accuracy: 0.9737 - val_loss: 0.0832
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9751 - loss: 0.0784 - val_accuracy: 0.9767 - val_loss: 0.0755
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9793 - loss: 0.0691 - val_accuracy: 0.9740 - val_loss: 0.0813
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9839 - loss: 0.0563 - val_accuracy: 0.9745 - val_loss: 0.0854
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9875 - loss: 0.0469 - val_accuracy: 0.9802 - val_loss: 0.0702
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9894 - loss: 0.0408 - val_accuracy: 0.9772 - val_loss: 0.0717
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9909 - loss: 0.0370 - val_accuracy: 0.9790 - val_loss: 0.0733
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9921 - loss: 0.0336 - val_accuracy: 0.9783 - val_loss: 0.0694
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - accuracy: 0.9941 - loss: 0.0276 - val_accuracy: 0.9816 - val_loss: 0.0607
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9812
# 🔹 Precision: 0.9740
# 🔹 Recall: 0.9834
# 🔹 F1_score: 0.9787
# ✔️ Fold 1 F1-score: 0.9787
# Fold 2
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9040 - loss: 0.2538 - val_accuracy: 0.9581 - val_loss: 0.1301
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9532 - loss: 0.1346 - val_accuracy: 0.9670 - val_loss: 0.0964
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9718 - loss: 0.0873 - val_accuracy: 0.9721 - val_loss: 0.0835
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9798 - loss: 0.0656 - val_accuracy: 0.9660 - val_loss: 0.1039
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9815 - loss: 0.0589 - val_accuracy: 0.9760 - val_loss: 0.0734
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9864 - loss: 0.0485 - val_accuracy: 0.9786 - val_loss: 0.0723
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9883 - loss: 0.0418 - val_accuracy: 0.9784 - val_loss: 0.0716
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9906 - loss: 0.0394 - val_accuracy: 0.9786 - val_loss: 0.0723
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9926 - loss: 0.0316 - val_accuracy: 0.9806 - val_loss: 0.0677
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9934 - loss: 0.0300 - val_accuracy: 0.9808 - val_loss: 0.0658
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9796
# 🔹 Precision: 0.9716
# 🔹 Recall: 0.9820
# 🔹 F1_score: 0.9768
# ✔️ Fold 2 F1-score: 0.9768
# Fold 3
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.9069 - loss: 0.2473 - val_accuracy: 0.9612 - val_loss: 0.1139
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9626 - loss: 0.1105 - val_accuracy: 0.9688 - val_loss: 0.0941
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9744 - loss: 0.0814 - val_accuracy: 0.9738 - val_loss: 0.0797
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9816 - loss: 0.0609 - val_accuracy: 0.9789 - val_loss: 0.0697
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9859 - loss: 0.0500 - val_accuracy: 0.9800 - val_loss: 0.0640
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9884 - loss: 0.0442 - val_accuracy: 0.9807 - val_loss: 0.0631
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9913 - loss: 0.0364 - val_accuracy: 0.9793 - val_loss: 0.0736
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9922 - loss: 0.0338 - val_accuracy: 0.9814 - val_loss: 0.0696
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9922 - loss: 0.0335 - val_accuracy: 0.9803 - val_loss: 0.0662
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9801
# 🔹 Precision: 0.9779
# 🔹 Recall: 0.9766
# 🔹 F1_score: 0.9772
# ✔️ Fold 3 F1-score: 0.9772
# Fold 4
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.9033 - loss: 0.2546 - val_accuracy: 0.9516 - val_loss: 0.1408
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9635 - loss: 0.1133 - val_accuracy: 0.9702 - val_loss: 0.0932
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9754 - loss: 0.0779 - val_accuracy: 0.9772 - val_loss: 0.0761
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9814 - loss: 0.0645 - val_accuracy: 0.9764 - val_loss: 0.0743
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9862 - loss: 0.0493 - val_accuracy: 0.9807 - val_loss: 0.0669
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9883 - loss: 0.0441 - val_accuracy: 0.9782 - val_loss: 0.0694
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9900 - loss: 0.0403 - val_accuracy: 0.9813 - val_loss: 0.0664
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9925 - loss: 0.0337 - val_accuracy: 0.9808 - val_loss: 0.0661
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9934 - loss: 0.0309 - val_accuracy: 0.9804 - val_loss: 0.0659
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9939 - loss: 0.0269 - val_accuracy: 0.9816 - val_loss: 0.0652
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9815
# 🔹 Precision: 0.9810
# 🔹 Recall: 0.9766
# 🔹 F1_score: 0.9788
# ✔️ Fold 4 F1-score: 0.9788
# Fold 5
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9025 - loss: 0.2531 - val_accuracy: 0.9562 - val_loss: 0.1254
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9651 - loss: 0.1085 - val_accuracy: 0.9690 - val_loss: 0.0918
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9754 - loss: 0.0778 - val_accuracy: 0.9732 - val_loss: 0.0812
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9811 - loss: 0.0640 - val_accuracy: 0.9774 - val_loss: 0.0717
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9860 - loss: 0.0511 - val_accuracy: 0.9777 - val_loss: 0.0687
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9879 - loss: 0.0422 - val_accuracy: 0.9778 - val_loss: 0.0672
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9909 - loss: 0.0375 - val_accuracy: 0.9794 - val_loss: 0.0638
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9926 - loss: 0.0320 - val_accuracy: 0.9804 - val_loss: 0.0645
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9939 - loss: 0.0280 - val_accuracy: 0.9802 - val_loss: 0.0668
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9944 - loss: 0.0259 - val_accuracy: 0.9793 - val_loss: 0.0655
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9793
# 🔹 Precision: 0.9755
# 🔹 Recall: 0.9771
# 🔹 F1_score: 0.9763
# ✔️ Fold 5 F1-score: 0.9763
# Average F1-score: 0.9776
#
#  Testing lstm_units=128, dropout_rate=0.3
# Fold 1
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8887 - loss: 0.2788 - val_accuracy: 0.9573 - val_loss: 0.1333
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9619 - loss: 0.1175 - val_accuracy: 0.9689 - val_loss: 0.0950
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9725 - loss: 0.0866 - val_accuracy: 0.9751 - val_loss: 0.0796
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9779 - loss: 0.0722 - val_accuracy: 0.9756 - val_loss: 0.0797
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9822 - loss: 0.0599 - val_accuracy: 0.9773 - val_loss: 0.0742
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9849 - loss: 0.0542 - val_accuracy: 0.9778 - val_loss: 0.0718
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9873 - loss: 0.0454 - val_accuracy: 0.9740 - val_loss: 0.0786
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9890 - loss: 0.0423 - val_accuracy: 0.9784 - val_loss: 0.0720
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9908 - loss: 0.0362 - val_accuracy: 0.9783 - val_loss: 0.0720
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9785
# 🔹 Precision: 0.9658
# 🔹 Recall: 0.9858
# 🔹 F1_score: 0.9757
# ✔️ Fold 1 F1-score: 0.9757
# Fold 2
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.8916 - loss: 0.2749 - val_accuracy: 0.9504 - val_loss: 0.1411
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9566 - loss: 0.1256 - val_accuracy: 0.9585 - val_loss: 0.1193
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9679 - loss: 0.0961 - val_accuracy: 0.9726 - val_loss: 0.0859
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9759 - loss: 0.0752 - val_accuracy: 0.9742 - val_loss: 0.0797
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9795 - loss: 0.0649 - val_accuracy: 0.9759 - val_loss: 0.0764
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9839 - loss: 0.0551 - val_accuracy: 0.9771 - val_loss: 0.0713
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9851 - loss: 0.0513 - val_accuracy: 0.9771 - val_loss: 0.0709
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9875 - loss: 0.0426 - val_accuracy: 0.9774 - val_loss: 0.0738
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9896 - loss: 0.0396 - val_accuracy: 0.9791 - val_loss: 0.0643
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.9903 - loss: 0.0365 - val_accuracy: 0.9781 - val_loss: 0.0719
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9796
# 🔹 Precision: 0.9777
# 🔹 Recall: 0.9756
# 🔹 F1_score: 0.9766
# ✔️ Fold 2 F1-score: 0.9766
# Fold 3
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8907 - loss: 0.2746 - val_accuracy: 0.9464 - val_loss: 0.1542
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9595 - loss: 0.1250 - val_accuracy: 0.9659 - val_loss: 0.1035
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9719 - loss: 0.0895 - val_accuracy: 0.9755 - val_loss: 0.0824
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9743 - loss: 0.0782 - val_accuracy: 0.9727 - val_loss: 0.0882
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9791 - loss: 0.0708 - val_accuracy: 0.9774 - val_loss: 0.0742
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9828 - loss: 0.0566 - val_accuracy: 0.9777 - val_loss: 0.0749
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9874 - loss: 0.0478 - val_accuracy: 0.9807 - val_loss: 0.0632
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9879 - loss: 0.0429 - val_accuracy: 0.9802 - val_loss: 0.0678
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9905 - loss: 0.0372 - val_accuracy: 0.9810 - val_loss: 0.0625
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9911 - loss: 0.0346 - val_accuracy: 0.9826 - val_loss: 0.0588
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9811
# 🔹 Precision: 0.9801
# 🔹 Recall: 0.9766
# 🔹 F1_score: 0.9783
# ✔️ Fold 3 F1-score: 0.9783
# Fold 4
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8952 - loss: 0.2681 - val_accuracy: 0.9558 - val_loss: 0.1306
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9573 - loss: 0.1259 - val_accuracy: 0.9645 - val_loss: 0.1022
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9723 - loss: 0.0885 - val_accuracy: 0.9651 - val_loss: 0.1051
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9755 - loss: 0.0793 - val_accuracy: 0.9727 - val_loss: 0.0883
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9802 - loss: 0.0645 - val_accuracy: 0.9762 - val_loss: 0.0738
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9836 - loss: 0.0547 - val_accuracy: 0.9640 - val_loss: 0.1096
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9825 - loss: 0.0592 - val_accuracy: 0.9770 - val_loss: 0.0759
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9887 - loss: 0.0424 - val_accuracy: 0.9784 - val_loss: 0.0718
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9895 - loss: 0.0419 - val_accuracy: 0.9781 - val_loss: 0.0720
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9916 - loss: 0.0362 - val_accuracy: 0.9790 - val_loss: 0.0696
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9797
# 🔹 Precision: 0.9820
# 🔹 Recall: 0.9715
# 🔹 F1_score: 0.9767
# ✔️ Fold 4 F1-score: 0.9767
# Fold 5
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8910 - loss: 0.2751 - val_accuracy: 0.9558 - val_loss: 0.1341
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9570 - loss: 0.1312 - val_accuracy: 0.9619 - val_loss: 0.1093
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9711 - loss: 0.0905 - val_accuracy: 0.9715 - val_loss: 0.0889
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9767 - loss: 0.0727 - val_accuracy: 0.9702 - val_loss: 0.0857
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9810 - loss: 0.0611 - val_accuracy: 0.9746 - val_loss: 0.0787
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9839 - loss: 0.0550 - val_accuracy: 0.9764 - val_loss: 0.0769
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9870 - loss: 0.0461 - val_accuracy: 0.9772 - val_loss: 0.0774
# Epoch 8/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9863 - loss: 0.0503 - val_accuracy: 0.9784 - val_loss: 0.0680
# Epoch 9/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9898 - loss: 0.0383 - val_accuracy: 0.9796 - val_loss: 0.0663
# Epoch 10/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9928 - loss: 0.0324 - val_accuracy: 0.9769 - val_loss: 0.0725
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9793
# 🔹 Precision: 0.9746
# 🔹 Recall: 0.9781
# 🔹 F1_score: 0.9763
# ✔️ Fold 5 F1-score: 0.9763
# Average F1-score: 0.9767
# Best Parameters Found:
# LSTM Units: 128
# Dropout Rate: 0.2
# Best F1-Score: 0.9776
# CPU times: user 56min 56s, sys: 14min 58s, total: 1h 11min 55s
# Wall time: 56min 36s
# {'lstm_units': 128, 'dropout_rate': 0.2}

# %% [markdown]
# ### Train the model

# %%
# %%time

model = train_model(train_data, val_data, lstm_units=best_params["lstm_units"], dropout_rate=best_params["dropout_rate"])
model.summary()
# Out:
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.9015 - loss: 0.2472 - val_accuracy: 0.9691 - val_loss: 0.1048
# Epoch 2/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.9678 - loss: 0.0997 - val_accuracy: 0.9704 - val_loss: 0.0883
# Epoch 3/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 13s 16ms/step - accuracy: 0.9747 - loss: 0.0778 - val_accuracy: 0.9798 - val_loss: 0.0691
# Epoch 4/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.9804 - loss: 0.0616 - val_accuracy: 0.9790 - val_loss: 0.0682
# Epoch 5/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.9869 - loss: 0.0483 - val_accuracy: 0.9803 - val_loss: 0.0692
# Epoch 6/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.9891 - loss: 0.0420 - val_accuracy: 0.9795 - val_loss: 0.0656
# Epoch 7/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.9913 - loss: 0.0351 - val_accuracy: 0.9787 - val_loss: 0.0660
# Epoch 8/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.9920 - loss: 0.0337 - val_accuracy: 0.9803 - val_loss: 0.0632
# Epoch 9/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.9935 - loss: 0.0302 - val_accuracy: 0.9828 - val_loss: 0.0641
# Epoch 10/10
# 851/851 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.9950 - loss: 0.0260 - val_accuracy: 0.9803 - val_loss: 0.0697
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9817
# 🔹 Precision: 0.9749
# 🔹 Recall: 0.9834
# 🔹 F1_score: 0.9791
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_29 (Embedding)        │ (None, 300, 100)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_29 (LSTM)                  │ (None, 128)            │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,352,133 (12.79 MB)
#  Trainable params: 1,117,377 (4.26 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,234,756 (8.52 MB)
# CPU times: user 3min, sys: 45.9 s, total: 3min 46s
# Wall time: 2min 55s

# %% [markdown]
# ### Save the model in .keras

# %%
model.save("results/LSTM_model_original.keras")

# %% [markdown]
# ### Load the model again to see if results are the same

# %%
# load model
from tensorflow.keras.models import load_model

model2 = load_model("results/LSTM_model_original.keras")
model2.summary()
# Out:
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_29 (Embedding)        │ (None, 300, 100)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_29 (LSTM)                  │ (None, 128)            │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,352,133 (12.79 MB)
#  Trainable params: 1,117,377 (4.26 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,234,756 (8.52 MB)

# %% [markdown]
# ### Model evaluation

# %%
# %%time

evaluate_model(model, train_data, val_data)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.9815
# Precision: 0.9760
# Recall: 0.9819
# F1: 0.9789
# CPU times: user 9.09 s, sys: 213 ms, total: 9.31 s
# Wall time: 9.45 s

# %%
# %%time

evaluate_model(model2, train_data, val_data)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.9798
# Precision: 0.9741
# Recall: 0.9800
# F1: 0.9770
# CPU times: user 9.11 s, sys: 194 ms, total: 9.31 s
# Wall time: 8.7 s

# %% [markdown]
# ### Load LLM-rewritten data

# %%
val_data_rewritten = datasets["rewritten_test"].to_pandas()
train_data_rewritten = datasets["rewritten_train"].to_pandas()
data_combined = pd.concat([train_data, train_data_rewritten, val_data, val_data_rewritten], ignore_index=True)
data_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120982 entries, 0 to 120981
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   label                   120982 non-null  int64
#  1   full_content            120982 non-null  object
#  2   processed_full_content  120982 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Model evaluation on rewritten data, using original training data

# %%
# %%time

evaluate_model(model, train_data, val_data_rewritten)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.8217
# Precision: 0.8388
# Recall: 0.7333
# F1: 0.7825
# CPU times: user 8.94 s, sys: 202 ms, total: 9.14 s
# Wall time: 8.57 s

# %%
# %%time

evaluate_model(model2, train_data, val_data_rewritten)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Accuracy: 0.8279
# Precision: 0.8464
# Recall: 0.7412
# F1: 0.7903
# CPU times: user 8.89 s, sys: 106 ms, total: 9 s
# Wall time: 9.09 s

# %% [markdown]
# ### Rerun grid search with rewritten data

# %%
# %%time

best_params_combined = do_grid_search(data_combined)
best_params_combined
# Out:
#  Testing lstm_units=64, dropout_rate=0.2
# Fold 1
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8466 - loss: 0.3540 - val_accuracy: 0.9093 - val_loss: 0.2217
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9299 - loss: 0.1848 - val_accuracy: 0.9393 - val_loss: 0.1640
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9423 - loss: 0.1546 - val_accuracy: 0.9447 - val_loss: 0.1469
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9488 - loss: 0.1371 - val_accuracy: 0.9490 - val_loss: 0.1423
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9565 - loss: 0.1209 - val_accuracy: 0.9499 - val_loss: 0.1381
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9612 - loss: 0.1116 - val_accuracy: 0.9514 - val_loss: 0.1320
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9650 - loss: 0.1018 - val_accuracy: 0.9506 - val_loss: 0.1349
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9691 - loss: 0.0936 - val_accuracy: 0.9522 - val_loss: 0.1336
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9704 - loss: 0.0892 - val_accuracy: 0.9523 - val_loss: 0.1327
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9519
# 🔹 Precision: 0.9410
# 🔹 Recall: 0.9496
# 🔹 F1_score: 0.9453
# ✔️ Fold 1 F1-score: 0.9453
# Fold 2
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8474 - loss: 0.3530 - val_accuracy: 0.9264 - val_loss: 0.1925
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9307 - loss: 0.1810 - val_accuracy: 0.9391 - val_loss: 0.1598
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9428 - loss: 0.1524 - val_accuracy: 0.9432 - val_loss: 0.1537
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9510 - loss: 0.1338 - val_accuracy: 0.9462 - val_loss: 0.1437
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9568 - loss: 0.1217 - val_accuracy: 0.9499 - val_loss: 0.1367
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.9612 - loss: 0.1118 - val_accuracy: 0.9510 - val_loss: 0.1368
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9642 - loss: 0.1014 - val_accuracy: 0.9516 - val_loss: 0.1343
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9672 - loss: 0.0972 - val_accuracy: 0.9534 - val_loss: 0.1341
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9704 - loss: 0.0893 - val_accuracy: 0.9532 - val_loss: 0.1367
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9734 - loss: 0.0820 - val_accuracy: 0.9526 - val_loss: 0.1333
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9538
# 🔹 Precision: 0.9502
# 🔹 Recall: 0.9437
# 🔹 F1_score: 0.9470
# ✔️ Fold 2 F1-score: 0.9470
# Fold 3
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8471 - loss: 0.3564 - val_accuracy: 0.9230 - val_loss: 0.1927
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9310 - loss: 0.1820 - val_accuracy: 0.9386 - val_loss: 0.1622
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9440 - loss: 0.1513 - val_accuracy: 0.9405 - val_loss: 0.1552
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9501 - loss: 0.1355 - val_accuracy: 0.9453 - val_loss: 0.1461
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.9563 - loss: 0.1208 - val_accuracy: 0.9471 - val_loss: 0.1388
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9610 - loss: 0.1105 - val_accuracy: 0.9480 - val_loss: 0.1407
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9651 - loss: 0.1005 - val_accuracy: 0.9511 - val_loss: 0.1345
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9683 - loss: 0.0938 - val_accuracy: 0.9507 - val_loss: 0.1350
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9713 - loss: 0.0872 - val_accuracy: 0.9513 - val_loss: 0.1392
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9725 - loss: 0.0826 - val_accuracy: 0.9528 - val_loss: 0.1371
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9508
# 🔹 Precision: 0.9434
# 🔹 Recall: 0.9441
# 🔹 F1_score: 0.9438
# ✔️ Fold 3 F1-score: 0.9438
# Fold 4
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8520 - loss: 0.3466 - val_accuracy: 0.9223 - val_loss: 0.1935
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9307 - loss: 0.1826 - val_accuracy: 0.9342 - val_loss: 0.1681
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9442 - loss: 0.1509 - val_accuracy: 0.9428 - val_loss: 0.1545
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9522 - loss: 0.1312 - val_accuracy: 0.9470 - val_loss: 0.1454
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9578 - loss: 0.1176 - val_accuracy: 0.9464 - val_loss: 0.1450
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9632 - loss: 0.1069 - val_accuracy: 0.9494 - val_loss: 0.1473
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9675 - loss: 0.0965 - val_accuracy: 0.9523 - val_loss: 0.1370
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9693 - loss: 0.0910 - val_accuracy: 0.9511 - val_loss: 0.1471
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9734 - loss: 0.0813 - val_accuracy: 0.9509 - val_loss: 0.1447
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9746 - loss: 0.0781 - val_accuracy: 0.9530 - val_loss: 0.1465
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9495
# 🔹 Precision: 0.9421
# 🔹 Recall: 0.9424
# 🔹 F1_score: 0.9422
# ✔️ Fold 4 F1-score: 0.9422
# Fold 5
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8520 - loss: 0.3455 - val_accuracy: 0.9303 - val_loss: 0.1881
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9297 - loss: 0.1856 - val_accuracy: 0.9405 - val_loss: 0.1598
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9426 - loss: 0.1562 - val_accuracy: 0.9466 - val_loss: 0.1440
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9503 - loss: 0.1361 - val_accuracy: 0.9504 - val_loss: 0.1368
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9572 - loss: 0.1218 - val_accuracy: 0.9504 - val_loss: 0.1371
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9603 - loss: 0.1106 - val_accuracy: 0.9528 - val_loss: 0.1307
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9655 - loss: 0.1015 - val_accuracy: 0.9528 - val_loss: 0.1313
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9684 - loss: 0.0946 - val_accuracy: 0.9531 - val_loss: 0.1306
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9684 - loss: 0.0958 - val_accuracy: 0.9545 - val_loss: 0.1333
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9736 - loss: 0.0827 - val_accuracy: 0.9545 - val_loss: 0.1352
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9531
# 🔹 Precision: 0.9461
# 🔹 Recall: 0.9468
# 🔹 F1_score: 0.9464
# ✔️ Fold 5 F1-score: 0.9464
# Average F1-score: 0.9449
#
#  Testing lstm_units=64, dropout_rate=0.3
# Fold 1
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8365 - loss: 0.3756 - val_accuracy: 0.9219 - val_loss: 0.2076
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9224 - loss: 0.2018 - val_accuracy: 0.9331 - val_loss: 0.1730
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9354 - loss: 0.1692 - val_accuracy: 0.9416 - val_loss: 0.1563
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9447 - loss: 0.1485 - val_accuracy: 0.9423 - val_loss: 0.1523
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9492 - loss: 0.1372 - val_accuracy: 0.9441 - val_loss: 0.1452
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9548 - loss: 0.1255 - val_accuracy: 0.9483 - val_loss: 0.1425
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9582 - loss: 0.1174 - val_accuracy: 0.9486 - val_loss: 0.1363
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9609 - loss: 0.1119 - val_accuracy: 0.9500 - val_loss: 0.1362
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 32s 21ms/step - accuracy: 0.9633 - loss: 0.1059 - val_accuracy: 0.9502 - val_loss: 0.1386
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9652 - loss: 0.1039 - val_accuracy: 0.9503 - val_loss: 0.1392
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9511
# 🔹 Precision: 0.9481
# 🔹 Recall: 0.9395
# 🔹 F1_score: 0.9438
# ✔️ Fold 1 F1-score: 0.9438
# Fold 2
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.8251 - loss: 0.3828 - val_accuracy: 0.9162 - val_loss: 0.2099
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9196 - loss: 0.2034 - val_accuracy: 0.9327 - val_loss: 0.1759
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9363 - loss: 0.1680 - val_accuracy: 0.9410 - val_loss: 0.1580
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9437 - loss: 0.1512 - val_accuracy: 0.9394 - val_loss: 0.1584
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9479 - loss: 0.1388 - val_accuracy: 0.9418 - val_loss: 0.1557
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9536 - loss: 0.1288 - val_accuracy: 0.9479 - val_loss: 0.1395
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9562 - loss: 0.1208 - val_accuracy: 0.9498 - val_loss: 0.1367
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9604 - loss: 0.1123 - val_accuracy: 0.9482 - val_loss: 0.1411
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9633 - loss: 0.1053 - val_accuracy: 0.9480 - val_loss: 0.1381
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9650 - loss: 0.1008 - val_accuracy: 0.9481 - val_loss: 0.1423
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9481
# 🔹 Precision: 0.9464
# 🔹 Recall: 0.9342
# 🔹 F1_score: 0.9403
# ✔️ Fold 2 F1-score: 0.9403
# Fold 3
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8283 - loss: 0.3884 - val_accuracy: 0.9133 - val_loss: 0.2192
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9163 - loss: 0.2155 - val_accuracy: 0.9253 - val_loss: 0.1979
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9315 - loss: 0.1804 - val_accuracy: 0.9354 - val_loss: 0.1676
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9410 - loss: 0.1576 - val_accuracy: 0.9410 - val_loss: 0.1574
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9461 - loss: 0.1449 - val_accuracy: 0.9432 - val_loss: 0.1504
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9520 - loss: 0.1332 - val_accuracy: 0.9448 - val_loss: 0.1463
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9558 - loss: 0.1245 - val_accuracy: 0.9442 - val_loss: 0.1468
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9599 - loss: 0.1145 - val_accuracy: 0.9467 - val_loss: 0.1402
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9598 - loss: 0.1132 - val_accuracy: 0.9473 - val_loss: 0.1417
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9643 - loss: 0.1047 - val_accuracy: 0.9488 - val_loss: 0.1376
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9497
# 🔹 Precision: 0.9463
# 🔹 Recall: 0.9383
# 🔹 F1_score: 0.9423
# ✔️ Fold 3 F1-score: 0.9423
# Fold 4
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.8382 - loss: 0.3765 - val_accuracy: 0.9147 - val_loss: 0.2188
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9151 - loss: 0.2207 - val_accuracy: 0.9229 - val_loss: 0.1995
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9280 - loss: 0.1897 - val_accuracy: 0.9311 - val_loss: 0.1828
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9370 - loss: 0.1699 - val_accuracy: 0.9331 - val_loss: 0.1700
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9433 - loss: 0.1540 - val_accuracy: 0.9392 - val_loss: 0.1610
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9479 - loss: 0.1408 - val_accuracy: 0.9437 - val_loss: 0.1574
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9532 - loss: 0.1319 - val_accuracy: 0.9405 - val_loss: 0.1546
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9548 - loss: 0.1280 - val_accuracy: 0.9458 - val_loss: 0.1574
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9567 - loss: 0.1215 - val_accuracy: 0.9462 - val_loss: 0.1511
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9615 - loss: 0.1112 - val_accuracy: 0.9471 - val_loss: 0.1492
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9458
# 🔹 Precision: 0.9474
# 🔹 Recall: 0.9276
# 🔹 F1_score: 0.9374
# ✔️ Fold 4 F1-score: 0.9374
# Fold 5
#
# 🚀 Training LSTM with lstm_units=64, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8317 - loss: 0.3794 - val_accuracy: 0.9206 - val_loss: 0.2035
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9218 - loss: 0.2072 - val_accuracy: 0.9359 - val_loss: 0.1704
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9372 - loss: 0.1681 - val_accuracy: 0.9388 - val_loss: 0.1620
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9431 - loss: 0.1495 - val_accuracy: 0.9442 - val_loss: 0.1499
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9499 - loss: 0.1357 - val_accuracy: 0.9468 - val_loss: 0.1427
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9534 - loss: 0.1270 - val_accuracy: 0.9491 - val_loss: 0.1418
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9578 - loss: 0.1181 - val_accuracy: 0.9509 - val_loss: 0.1341
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9614 - loss: 0.1108 - val_accuracy: 0.9514 - val_loss: 0.1334
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9633 - loss: 0.1066 - val_accuracy: 0.9532 - val_loss: 0.1291
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9651 - loss: 0.1002 - val_accuracy: 0.9519 - val_loss: 0.1360
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9534
# 🔹 Precision: 0.9425
# 🔹 Recall: 0.9516
# 🔹 F1_score: 0.9470
# ✔️ Fold 5 F1-score: 0.9470
# Average F1-score: 0.9422
#
#  Testing lstm_units=128, dropout_rate=0.2
# Fold 1
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.8654 - loss: 0.3155 - val_accuracy: 0.9300 - val_loss: 0.1797
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9339 - loss: 0.1703 - val_accuracy: 0.9407 - val_loss: 0.1522
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9451 - loss: 0.1435 - val_accuracy: 0.9467 - val_loss: 0.1399
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9524 - loss: 0.1245 - val_accuracy: 0.9496 - val_loss: 0.1331
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9601 - loss: 0.1088 - val_accuracy: 0.9510 - val_loss: 0.1278
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9642 - loss: 0.1001 - val_accuracy: 0.9529 - val_loss: 0.1247
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9687 - loss: 0.0894 - val_accuracy: 0.9421 - val_loss: 0.1557
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9710 - loss: 0.0834 - val_accuracy: 0.9540 - val_loss: 0.1239
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9752 - loss: 0.0748 - val_accuracy: 0.9534 - val_loss: 0.1269
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9776 - loss: 0.0703 - val_accuracy: 0.9538 - val_loss: 0.1313
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9543
# 🔹 Precision: 0.9471
# 🔹 Recall: 0.9486
# 🔹 F1_score: 0.9478
# ✔️ Fold 1 F1-score: 0.9478
# Fold 2
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8611 - loss: 0.3224 - val_accuracy: 0.9283 - val_loss: 0.1796
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9373 - loss: 0.1618 - val_accuracy: 0.9456 - val_loss: 0.1438
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9483 - loss: 0.1343 - val_accuracy: 0.9487 - val_loss: 0.1318
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9563 - loss: 0.1160 - val_accuracy: 0.9507 - val_loss: 0.1299
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9625 - loss: 0.1030 - val_accuracy: 0.9511 - val_loss: 0.1275
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9661 - loss: 0.0935 - val_accuracy: 0.9548 - val_loss: 0.1208
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9700 - loss: 0.0843 - val_accuracy: 0.9555 - val_loss: 0.1237
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9736 - loss: 0.0771 - val_accuracy: 0.9552 - val_loss: 0.1266
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9761 - loss: 0.0714 - val_accuracy: 0.9545 - val_loss: 0.1245
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9553
# 🔹 Precision: 0.9505
# 🔹 Recall: 0.9471
# 🔹 F1_score: 0.9488
# ✔️ Fold 2 F1-score: 0.9488
# Fold 3
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8625 - loss: 0.3255 - val_accuracy: 0.9302 - val_loss: 0.1770
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9370 - loss: 0.1620 - val_accuracy: 0.9412 - val_loss: 0.1512
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9490 - loss: 0.1354 - val_accuracy: 0.9459 - val_loss: 0.1422
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9572 - loss: 0.1168 - val_accuracy: 0.9483 - val_loss: 0.1337
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9617 - loss: 0.1061 - val_accuracy: 0.9519 - val_loss: 0.1307
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9674 - loss: 0.0928 - val_accuracy: 0.9495 - val_loss: 0.1317
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9701 - loss: 0.0862 - val_accuracy: 0.9516 - val_loss: 0.1303
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9739 - loss: 0.0787 - val_accuracy: 0.9516 - val_loss: 0.1311
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9769 - loss: 0.0711 - val_accuracy: 0.9531 - val_loss: 0.1391
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9794 - loss: 0.0654 - val_accuracy: 0.9524 - val_loss: 0.1319
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9507
# 🔹 Precision: 0.9428
# 🔹 Recall: 0.9447
# 🔹 F1_score: 0.9437
# ✔️ Fold 3 F1-score: 0.9437
# Fold 4
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.8654 - loss: 0.3146 - val_accuracy: 0.9324 - val_loss: 0.1764
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9355 - loss: 0.1624 - val_accuracy: 0.9392 - val_loss: 0.1518
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9480 - loss: 0.1353 - val_accuracy: 0.9452 - val_loss: 0.1420
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9565 - loss: 0.1156 - val_accuracy: 0.9478 - val_loss: 0.1350
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9622 - loss: 0.1033 - val_accuracy: 0.9507 - val_loss: 0.1306
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9667 - loss: 0.0935 - val_accuracy: 0.9527 - val_loss: 0.1333
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9699 - loss: 0.0860 - val_accuracy: 0.9526 - val_loss: 0.1379
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9728 - loss: 0.0789 - val_accuracy: 0.9550 - val_loss: 0.1388
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9499
# 🔹 Precision: 0.9550
# 🔹 Recall: 0.9291
# 🔹 F1_score: 0.9419
# ✔️ Fold 4 F1-score: 0.9419
# Fold 5
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8635 - loss: 0.3226 - val_accuracy: 0.9283 - val_loss: 0.1829
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9332 - loss: 0.1740 - val_accuracy: 0.9427 - val_loss: 0.1475
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9472 - loss: 0.1394 - val_accuracy: 0.9504 - val_loss: 0.1335
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9549 - loss: 0.1214 - val_accuracy: 0.9512 - val_loss: 0.1295
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9614 - loss: 0.1066 - val_accuracy: 0.9527 - val_loss: 0.1252
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9652 - loss: 0.0973 - val_accuracy: 0.9535 - val_loss: 0.1210
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9698 - loss: 0.0873 - val_accuracy: 0.9541 - val_loss: 0.1286
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9726 - loss: 0.0813 - val_accuracy: 0.9552 - val_loss: 0.1263
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - accuracy: 0.9755 - loss: 0.0750 - val_accuracy: 0.9547 - val_loss: 0.1288
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9559
# 🔹 Precision: 0.9510
# 🔹 Recall: 0.9479
# 🔹 F1_score: 0.9495
# ✔️ Fold 5 F1-score: 0.9495
# Average F1-score: 0.9464
#
#  Testing lstm_units=128, dropout_rate=0.3
# Fold 1
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8519 - loss: 0.3443 - val_accuracy: 0.9258 - val_loss: 0.1917
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9234 - loss: 0.1986 - val_accuracy: 0.9354 - val_loss: 0.1653
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9374 - loss: 0.1605 - val_accuracy: 0.9409 - val_loss: 0.1517
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9459 - loss: 0.1420 - val_accuracy: 0.9447 - val_loss: 0.1419
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9516 - loss: 0.1301 - val_accuracy: 0.9501 - val_loss: 0.1346
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9566 - loss: 0.1180 - val_accuracy: 0.9496 - val_loss: 0.1346
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9602 - loss: 0.1083 - val_accuracy: 0.9516 - val_loss: 0.1280
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9628 - loss: 0.1028 - val_accuracy: 0.9529 - val_loss: 0.1278
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9656 - loss: 0.0962 - val_accuracy: 0.9516 - val_loss: 0.1306
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9683 - loss: 0.0907 - val_accuracy: 0.9529 - val_loss: 0.1263
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9529
# 🔹 Precision: 0.9513
# 🔹 Recall: 0.9405
# 🔹 F1_score: 0.9458
# ✔️ Fold 1 F1-score: 0.9458
# Fold 2
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8515 - loss: 0.3415 - val_accuracy: 0.9267 - val_loss: 0.1857
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9297 - loss: 0.1797 - val_accuracy: 0.9393 - val_loss: 0.1559
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9428 - loss: 0.1473 - val_accuracy: 0.9448 - val_loss: 0.1452
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9515 - loss: 0.1298 - val_accuracy: 0.9497 - val_loss: 0.1334
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9560 - loss: 0.1178 - val_accuracy: 0.9506 - val_loss: 0.1310
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9597 - loss: 0.1090 - val_accuracy: 0.9544 - val_loss: 0.1263
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9632 - loss: 0.1021 - val_accuracy: 0.9513 - val_loss: 0.1271
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9653 - loss: 0.0963 - val_accuracy: 0.9495 - val_loss: 0.1265
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9684 - loss: 0.0880 - val_accuracy: 0.9528 - val_loss: 0.1251
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9696 - loss: 0.0841 - val_accuracy: 0.9525 - val_loss: 0.1273
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9542
# 🔹 Precision: 0.9612
# 🔹 Recall: 0.9329
# 🔹 F1_score: 0.9468
# ✔️ Fold 2 F1-score: 0.9468
# Fold 3
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8460 - loss: 0.3531 - val_accuracy: 0.9255 - val_loss: 0.1916
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9260 - loss: 0.1886 - val_accuracy: 0.9351 - val_loss: 0.1619
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9405 - loss: 0.1539 - val_accuracy: 0.9406 - val_loss: 0.1526
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9493 - loss: 0.1340 - val_accuracy: 0.9439 - val_loss: 0.1421
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9551 - loss: 0.1212 - val_accuracy: 0.9469 - val_loss: 0.1420
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9593 - loss: 0.1109 - val_accuracy: 0.9477 - val_loss: 0.1341
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9628 - loss: 0.1029 - val_accuracy: 0.9496 - val_loss: 0.1358
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9658 - loss: 0.0963 - val_accuracy: 0.9522 - val_loss: 0.1312
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9687 - loss: 0.0908 - val_accuracy: 0.9526 - val_loss: 0.1305
# Epoch 10/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9711 - loss: 0.0838 - val_accuracy: 0.9496 - val_loss: 0.1339
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9509
# 🔹 Precision: 0.9339
# 🔹 Recall: 0.9555
# 🔹 F1_score: 0.9446
# ✔️ Fold 3 F1-score: 0.9446
# Fold 4
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8529 - loss: 0.3408 - val_accuracy: 0.9224 - val_loss: 0.1872
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9273 - loss: 0.1810 - val_accuracy: 0.9368 - val_loss: 0.1615
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9424 - loss: 0.1488 - val_accuracy: 0.9439 - val_loss: 0.1471
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9494 - loss: 0.1307 - val_accuracy: 0.9453 - val_loss: 0.1426
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9553 - loss: 0.1191 - val_accuracy: 0.9481 - val_loss: 0.1374
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9589 - loss: 0.1089 - val_accuracy: 0.9483 - val_loss: 0.1333
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9626 - loss: 0.1012 - val_accuracy: 0.9497 - val_loss: 0.1427
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9668 - loss: 0.0939 - val_accuracy: 0.9509 - val_loss: 0.1400
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9686 - loss: 0.0891 - val_accuracy: 0.9523 - val_loss: 0.1352
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9479
# 🔹 Precision: 0.9472
# 🔹 Recall: 0.9329
# 🔹 F1_score: 0.9400
# ✔️ Fold 4 F1-score: 0.9400
# Fold 5
#
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.3
# Epoch 1/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8561 - loss: 0.3297 - val_accuracy: 0.9300 - val_loss: 0.1752
# Epoch 2/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - accuracy: 0.9320 - loss: 0.1727 - val_accuracy: 0.9419 - val_loss: 0.1499
# Epoch 3/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9436 - loss: 0.1448 - val_accuracy: 0.9452 - val_loss: 0.1397
# Epoch 4/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9506 - loss: 0.1285 - val_accuracy: 0.9484 - val_loss: 0.1328
# Epoch 5/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9564 - loss: 0.1172 - val_accuracy: 0.9508 - val_loss: 0.1300
# Epoch 6/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9603 - loss: 0.1075 - val_accuracy: 0.9537 - val_loss: 0.1222
# Epoch 7/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9644 - loss: 0.0987 - val_accuracy: 0.9535 - val_loss: 0.1264
# Epoch 8/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9668 - loss: 0.0924 - val_accuracy: 0.9554 - val_loss: 0.1222
# Epoch 9/10
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.9692 - loss: 0.0882 - val_accuracy: 0.9556 - val_loss: 0.1238
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9538
# 🔹 Precision: 0.9462
# 🔹 Recall: 0.9482
# 🔹 F1_score: 0.9472
# ✔️ Fold 5 F1-score: 0.9472
# Average F1-score: 0.9449
# Best Parameters Found:
# LSTM Units: 128
# Dropout Rate: 0.2
# Best F1-Score: 0.9464
# CPU times: user 1h 46min 45s, sys: 29min 52s, total: 2h 16min 38s
# Wall time: 1h 50min 43s
# {'lstm_units': 128, 'dropout_rate': 0.2}

# %% [markdown]
# ### Retrain the model with rewritten data

# %%
# %%time

train_data_combined = pd.concat([train_data, train_data_rewritten], ignore_index=True)
val_data_combined = pd.concat([val_data, val_data_rewritten], ignore_index=True)
model_combined = train_model(train_data_combined, val_data_combined, 
                             lstm_units=best_params_combined["lstm_units"], 
                             dropout_rate=best_params_combined["dropout_rate"])
model_combined.save("results/LSTM_model_combined.keras")
# Out:
# 🚀 Training LSTM with lstm_units=128, dropout_rate=0.2
# Epoch 1/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 29s 17ms/step - accuracy: 0.8596 - loss: 0.3229 - val_accuracy: 0.9279 - val_loss: 0.1830
# Epoch 2/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - accuracy: 0.9354 - loss: 0.1644 - val_accuracy: 0.9394 - val_loss: 0.1494
# Epoch 3/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 29s 17ms/step - accuracy: 0.9499 - loss: 0.1327 - val_accuracy: 0.9465 - val_loss: 0.1389
# Epoch 4/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - accuracy: 0.9576 - loss: 0.1143 - val_accuracy: 0.9475 - val_loss: 0.1363
# Epoch 5/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 28s 17ms/step - accuracy: 0.9628 - loss: 0.1023 - val_accuracy: 0.9497 - val_loss: 0.1330
# Epoch 6/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - accuracy: 0.9679 - loss: 0.0912 - val_accuracy: 0.9515 - val_loss: 0.1305
# Epoch 7/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - accuracy: 0.9712 - loss: 0.0829 - val_accuracy: 0.9523 - val_loss: 0.1313
# Epoch 8/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 27s 16ms/step - accuracy: 0.9745 - loss: 0.0754 - val_accuracy: 0.9520 - val_loss: 0.1345
# Epoch 9/10
# 1702/1702 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - accuracy: 0.9767 - loss: 0.0701 - val_accuracy: 0.9507 - val_loss: 0.1359
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 🏆 Training Results:
# 🔹 Accuracy: 0.9512
# 🔹 Precision: 0.9549
# 🔹 Recall: 0.9324
# 🔹 F1_score: 0.9435
# CPU times: user 5min 26s, sys: 1min 21s, total: 6min 47s
# Wall time: 5min 22s

# %%
evaluate_model(model_combined, train_data_combined, val_data_combined)
# Out:
# Evaluating Model
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Accuracy: 0.9538
# Precision: 0.9566
# Recall: 0.9369
# F1: 0.9467

# %%
evaluate_model(model_combined, train_data_combined, val_data)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.9792
# Precision: 0.9813
# Recall: 0.9709
# F1: 0.9761

# %%
evaluate_model(model_combined, train_data_combined, val_data_rewritten)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.9245
# Precision: 0.9287
# Recall: 0.8961
# F1: 0.9121

# %%
model_combined2 = load_model("results/LSTM_model_combined.keras")
model_combined2.summary()
# Out:
# Model: "sequential_51"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_51 (Embedding)        │ (None, 300, 100)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_51 (LSTM)                  │ (None, 128)            │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,352,133 (12.79 MB)
#  Trainable params: 1,117,377 (4.26 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,234,756 (8.52 MB)

# %%
evaluate_model(model_combined2, train_data_combined, val_data_combined)
# Out:
# Evaluating Model
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Accuracy: 0.9512
# Precision: 0.9518
# Recall: 0.9358
# F1: 0.9437

# %%
evaluate_model(model_combined2, train_data_combined, val_data)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.9813
# Precision: 0.9851
# Recall: 0.9720
# F1: 0.9785

# %%
evaluate_model(model_combined2, train_data_combined, val_data_rewritten)
# Out:
# Evaluating Model
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.9208
# Precision: 0.9241
# Recall: 0.8923
# F1: 0.9079
